# %%
pip install jupyter_contrib_nbextensions
# Out:
# ...
#   Using cached jupyter_contrib_nbextensions-0.5.1-py2.py3-none-any.whl (20.9 MB)
# ...
#   Using cached jupyter_nbextensions_configurator-0.4.1.tar.gz (479 kB)
# ...
#   Using cached jupyter_contrib_core-0.3.3-py2.py3-none-any.whl (18 kB)
# ...
#   Using cached jupyter_latex_envs-1.4.6.tar.gz (861 kB)
# ...
#
#   Using cached jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl (11 kB)
# ...
#   Created wheel for jupyter-latex-envs: filename=jupyter_latex_envs-1.4.6-py2.py3-none-any.whl size=963413 sha256=483dd57adc90ef8ed2d2ab224c18990681881ea4710819c583fd416eda6f3b13
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\f7\b5\78\f5b899dd8fc137fe0bfe26b382713f6d171c9eac2fb1fa091f
# ...
#   Created wheel for jupyter-nbextensions-configurator: filename=jupyter_nbextensions_configurator-0.4.1-py2.py3-none-any.whl size=465849 sha256=c205b426ebe48ed65101038bce947f34e169eb2d1f14330d7a35379117502c94
# ...
